# %%
import numpy as np
import pandas as pd

# %%
pd.set_option("display.max_rows", 130)
pd.set_option('max_colwidth', 250)

# %%
desc = pd.read_csv("data/HomeCredit_columns_description.csv",encoding= 'unicode_escape')
desc = desc[desc.Table == "application_{train|test}.csv"].drop(["Unnamed: 0", "Table"], axis=1)

# %%
desc
# Out:
#                               Row  \
# 0                      SK_ID_CURR
# 1                          TARGET
# 2              NAME_CONTRACT_TYPE
# 3                     CODE_GENDER
# 4                    FLAG_OWN_CAR
# 5                 FLAG_OWN_REALTY
# 6                    CNT_CHILDREN
# 7                AMT_INCOME_TOTAL
# 8                      AMT_CREDIT
# 9                     AMT_ANNUITY
# 10                AMT_GOODS_PRICE
# 11                NAME_TYPE_SUITE
# 12               NAME_INCOME_TYPE
# 13            NAME_EDUCATION_TYPE
# 14             NAME_FAMILY_STATUS
# 15              NAME_HOUSING_TYPE
# 16     REGION_POPULATION_RELATIVE
# 17                     DAYS_BIRTH
# 18                  DAYS_EMPLOYED
# 19              DAYS_REGISTRATION
# 20                DAYS_ID_PUBLISH
# 21                    OWN_CAR_AGE
# 22                     FLAG_MOBIL
# 23                 FLAG_EMP_PHONE
# 24                FLAG_WORK_PHONE
# 25               FLAG_CONT_MOBILE
# ...

# %%
row_to_desc = "OCCUPATION_TYPE"
desc[desc.Row == row_to_desc]["Description"]
# Out:
# 28    What kind of occupation does the client have
# Name: Description, dtype: object

# %%
list_col = ['OCCUPATION_TYPE', 'NAME_TYPE_SUITE', 'AMT_INCOME_TOTAL', 'CODE_GENDER',
       'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'DAYS_LAST_PHONE_CHANGE',
       'CNT_CHILDREN', 'AMT_CREDIT', 'ORGANIZATION_TYPE', 'AMT_ANNUITY',
       'NAME_CONTRACT_TYPE', 'REG_CITY_NOT_WORK_CITY',
       'HOUR_APPR_PROCESS_START', 'WEEKDAY_APPR_PROCESS_START',
       'REGION_RATING_CLIENT', 'FLAG_PHONE', 'FLAG_WORK_PHONE',
       'FLAG_EMP_PHONE', 'DAYS_ID_PUBLISH', 'DAYS_REGISTRATION',
       'DAYS_EMPLOYED', 'DAYS_BIRTH', 'REGION_POPULATION_RELATIVE',
       'NAME_HOUSING_TYPE', 'NAME_FAMILY_STATUS', 'NAME_EDUCATION_TYPE',
       'NAME_INCOME_TYPE', 'TARGET', "APARTMENTS_AVG"]

# %%
norm_list = []
for col in list_col:
    nor = desc[desc.Row == col]["Special"] == "normalized"
    if nor.values:
        norm_list.append(col)

# %%
norm_list
# Out:
# ['APARTMENTS_AVG']
